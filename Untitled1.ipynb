# %%
import pandas as pd
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
import pandas as pd

# %%
contribs=pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
merger_3 = pd.merge(props, contribs, on = "calaccess_committee_id" )
merger_3
# Out:
#                                             ocd_prop_id  calaccess_prop_id  \
# 0      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 5      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 6      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 7      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 8      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 9      ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 10     ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# ...

# %%
props.head(3)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
# 2                384                 1282321
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 1  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT
# ...

# %%
merger_3.groupby("committee_name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-904c6c05c7d0> in <module>()
# ----> 1 merger_3.groupby("committee_name")
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# ...

# %% [raw]
# merger_3

# %%
contribs.groupby("prop_name").sort_values("amount", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-59fe9d6e4ac6> in <module>()
# ----> 1 contribs.groupby("prop_name").sort_values("amount", ascending = False)
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/groupby.pyc in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# ...

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
contributions = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
com_name = [contributions.committee_name=="CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM, SPONSORED BY DRUG POLICY ACTION, YES ON PROP. 64"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-07ef94f0f7bd> in <module>()
# ----> 1 com_name = [contributions.committee_name=="CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM, SPONSORED BY DRUG POLICY ACTION, YES ON PROP. 64"]
#       2
#
# NameError: name 'contributions' is not defined

# %%
t_sum = contribs.amount.sum()

# %%
com_name
# Out:
#        calaccess_committee_id  \
# 29751                 1343793
# 29752                 1343793
# 29753                 1343793
# 29754                 1343793
# 29755                 1343793
# 29756                 1343793
# 29757                 1343793
# 29758                 1343793
# 29759                 1343793
# 29760                 1343793
# 29761                 1343793
# 29762                 1343793
# 29763                 1343793
# 29764                 1343793
# 29765                 1343793
# 29766                 1343793
# 29767                 1343793
# 29768                 1343793
# 29769                 1343793
# 29770                 1343793
# 29771                 1343793
# 29772                 1343793
# 29773                 1343793
# 29774                 1343793
# 29775                 1343793
# 29776                 1343793
# 29777                 1343793
# 29778                 1343793
# 29779                 1343793
# 29780                 1343793
# ...

# %%
mari = props[props.prop_name == "PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE." ]

# %%
prop = props[props.prop_name == "PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE." ]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-bf7d15852460> in <module>()
# ----> 1 contribs
#
# NameError: name 'contribs' is not defined

# %%
contribs=pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.value_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-2e256a1a5763> in <module>()
# ----> 1 contribs.value_counts
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
props.committee_position.value_counts()
props.head()
support = props[props.committee_position == "SUPPORT"]
support

oppose = props[props.committee_position =="OPPOSE"]
oppose




merger_2 = pd.merge(props, contribs, on = "calaccess_committee_id")
merger_2

merger_2.groupby("contributor_firstname").amount.sum().reset_index().sort_values("amount",ascending=False)
# Out:
#       contributor_firstname       amount
# 12293             THOMAS F.  11500000.00
# 12282                THOMAS  10651628.92
# 11346                  SEAN   9153234.15
# 9421               NICHOLAS   4255884.12
# 6804                  JULIE   2197066.00
# 10345                  REED   2000250.00
# 3077                DEAN A.   2000000.00
# 7450                L. JOHN   2000000.00
# 6324                   JOAN   1504515.00
# 2808                 DANIEL   1311218.72
# 8508                   MARK   1073949.61
# 9820                   PAUL   1034866.62
# 5258                  HENRY   1012487.88
# 5273               HENRY T.    800000.00
# 5                A. JERROLD    700000.00
# 3619                 DUSTIN    600360.00
# 8956             MICHAEL R.    500150.00
# 4780              GEORGE M.    500000.00
# 3011                  DAVID    468753.20
# 11986                 SUSAN    426981.20
# 10594           ROBERT ALAN    350000.00
# 9915                  PETER    327454.88
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 792.0+ bytes

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-9bc08a2f44f2> in <module>()
# ----> 1 pd.merge(prop, contribs, on="calaccess_filing_id")
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/reshape/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# /Users/taehoon/Code/first-python-notebook/lib/python2.7/site-packages/pandas/core/reshape/merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
# ...

# %%
pd.merge(prop, contribs, on="calaccess_committee_id")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
props.committee_name.value_counts(), reset_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-a7152c3d5646> in <module>()
# ----> 1 props.committee_name.value_counts(), reset_index
#
# NameError: name 'reset_index' is not defined

# %%
merger.committee_position.filter([like="SUPPORT"])
# Out:
#   File "<ipython-input-199-5d3caa7d3e49>", line 1
#     merger.committee_position.filter([like="SUPPORT"])
#                                           ^
# SyntaxError: invalid syntax

# %%
support = merger[merger.committee_position == "SUPPORT"]
oppose = merger[merger.committee_position == "OPPOSE"]

# %%
merged = pd.merge(contribs, props, on = "calaccess_committee_id")

# %%
s_sum = support.amount.sum()

# %%
contribs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-bf7d15852460> in <module>()
# ----> 1 contribs
#
# NameError: name 'contribs' is not defined

# %%
print "Hello World"
